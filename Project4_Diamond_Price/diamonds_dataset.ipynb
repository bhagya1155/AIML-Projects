# %%
import pandas as pd
df = pd.read_csv("/content/diamonds_dataset.csv.zip")

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df.head()
# Out:
#          id                                                url    shape  \
# 0  10086429  https://www.brilliantearth.com//loose-diamonds...    Round
# 1  10016334  https://www.brilliantearth.com//loose-diamonds...  Emerald
# 2   9947216  https://www.brilliantearth.com//loose-diamonds...  Emerald
# 3  10083437  https://www.brilliantearth.com//loose-diamonds...    Round
# 4   9946136  https://www.brilliantearth.com//loose-diamonds...  Emerald
#
#    price  carat        cut color clarity report     type         date_fetched
# 0    400   0.30  Very Good     J     SI2    GIA  natural  2020-11-29 12-26 PM
# 1    400   0.31      Ideal     I     SI1    GIA  natural  2020-11-29 12-26 PM
# 2    400   0.30      Ideal     I     VS2    GIA  natural  2020-11-29 12-26 PM
# 3    400   0.30      Ideal     I     SI2    GIA  natural  2020-11-29 12-26 PM
# 4    400   0.30      Ideal     I     SI1    GIA  natural  2020-11-29 12-26 PM

# %%
df.tail()
# Out:
#               id                                                url    shape  \
# 119302  10081678  https://www.brilliantearth.com//lab-diamonds-s...    Round
# 119303   9521564  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
# 119304   9896730  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
# 119305   9756570  https://www.brilliantearth.com//lab-diamonds-s...     Oval
# 119306   9293400  https://www.brilliantearth.com//lab-diamonds-s...  Cushion
#
#          price  carat          cut color clarity report type  \
# 119302   99040   5.71  Super Ideal     D    VVS2   GCAL  lab
# 119303  107330  15.32    Very Good     G     SI2    IGI  lab
# 119304  110110  10.05        Ideal     D     SI2    IGI  lab
# 119305  126030  10.33         Fair     D     VS2    IGI  lab
# 119306  141710  10.25         Good     E     VS1    IGI  lab
#
#                date_fetched
# 119302  2020-11-29 12-26 PM
# 119303  2020-11-29 12-26 PM
# 119304  2020-11-29 12-26 PM
# ...

# %%
print(df.shape)
# Out:
# (119307, 11)

# %%
print(df.columns)
# Out:
# Index(['id', 'url', 'shape', 'price', 'carat', 'cut', 'color', 'clarity',
#        'report', 'type', 'date_fetched'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 119307 entries, 0 to 119306
# Data columns (total 11 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            119307 non-null  int64
#  1   url           119307 non-null  object
#  2   shape         119307 non-null  object
#  3   price         119307 non-null  int64
#  4   carat         119307 non-null  float64
#  5   cut           119307 non-null  object
#  6   color         119307 non-null  object
#  7   clarity       119307 non-null  object
#  8   report        119307 non-null  object
#  9   type          119307 non-null  object
#  10  date_fetched  119307 non-null  object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 10.0+ MB

# %%
df.describe()
# Out:
#                  id         price          carat
# count  1.193070e+05  1.193070e+05  119307.000000
# mean   9.905507e+06  3.286843e+03       0.884169
# std    2.373824e+05  9.114695e+03       0.671141
# min    4.367730e+05  2.700000e+02       0.250000
# 25%    9.854352e+06  9.000000e+02       0.400000
# 50%    9.978096e+06  1.770000e+03       0.700000
# 75%    1.005433e+07  3.490000e+03       1.100000
# max    1.009225e+07  1.348720e+06      15.320000

# %%
df.isnull().sum()
# Out:
# id              0
# url             0
# shape           0
# price           0
# carat           0
# cut             0
# color           0
# clarity         0
# report          0
# type            0
# date_fetched    0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
print(df.mean(numeric_only=True))
# Out:
# id       9.905507e+06
# price    3.286843e+03
# carat    8.841687e-01
# dtype: float64

# %%
print(df.median(numeric_only=True))
# Out:
# id       9978096.0
# price       1770.0
# carat          0.7
# dtype: float64

# %%
print(df.var(numeric_only=True))
# Out:
# id       5.635039e+10
# price    8.307767e+07
# carat    4.504299e-01
# dtype: float64

# %%
print(df.mode().iloc[0])
# Out:
# id                                                         436773
# url             https://www.brilliantearth.com//lab-diamonds-s...
# shape                                                       Round
# price                                                       780.0
# carat                                                         0.3
# cut                                                   Super Ideal
# color                                                           E
# clarity                                                       VS1
# report                                                        GIA
# type                                                      natural
# date_fetched                                  2020-11-29 12-26 PM
# Name: 0, dtype: object

# %%
print(df.std(numeric_only=True))
# Out:
# id       237382.378523
# price      9114.695376
# carat         0.671141
# dtype: float64

# %%
correlation = df.corr(numeric_only=True)
print(correlation)
# Out:
#              id     price     carat
# id     1.000000  0.041761  0.072422
# price  0.041761  1.000000  0.555578
# carat  0.072422  0.555578  1.000000

# %%
plt.figure(figsize=(10,8))
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()

# %%
print(df["shape"].value_counts())
print(df["cut"].value_counts())
print(df["color"].value_counts())
print(df["clarity"].value_counts())
# Out:
# shape
# Round       76080
# Oval        12978
# Pear         9221
# Emerald      6750
# Princess     5135
# Cushion      4279
# Marquise     1740
# Heart        1374
# Radiant      1100
# Asscher       650
# Name: count, dtype: int64
# cut
# Super Ideal    55244
# Ideal          39417
# Very Good      20914
# Good            3398
# Fair             334
# Name: count, dtype: int64
# color
# E    24730
# D    20896
# F    19833
# G    17559
# I    14409
# H    12868
# J     9012
# Name: count, dtype: int64
# clarity
# VS1     27259
# VS2     26440
# SI1     21205
# VVS2    17229
# SI2     12771
# VVS1    10534
# IF       3667
# FL        202
# Name: count, dtype: int64

# %%
plt.scatter(df["carat"], df["price"])
plt.xlabel("Carat")
plt.ylabel("Price")
plt.title("Carat vs Price")
plt.show()

# %%
plt.hist(df["price"], bins=20)
plt.title("Price Distribution")
plt.xlabel("Price")
plt.ylabel("Frequency")
plt.show()

# %%
df["cut"].value_counts().plot(kind="bar")
plt.title("Diamond Cut Distribution")
plt.xlabel("Cut")
plt.ylabel("Count")
plt.show()

# %%
print(df[["carat", "price"]].describe())
# Out:
#                carat         price
# count  119307.000000  1.193070e+05
# mean        0.884169  3.286843e+03
# std         0.671141  9.114695e+03
# min         0.250000  2.700000e+02
# 25%         0.400000  9.000000e+02
# 50%         0.700000  1.770000e+03
# 75%         1.100000  3.490000e+03
# max        15.320000  1.348720e+06

# %%
print("""
BUSINESS INSIGHT REPORT

1. Dataset was cleaned by checking missing values and removing duplicates.
2. Statistical measures such as mean, median, mode, variance, and standard deviation were calculated.
3. Correlation analysis showed relationships among numerical variables.
4. Outliers in diamond prices were identified using a box plot.
5. Scatter plot showed that larger carat diamonds generally have higher prices.
6. Bar chart displayed the distribution of diamond cuts.
7. Histogram showed the distribution of diamond prices.

Conclusion:
Diamond price is strongly influenced by carat weight, while cut, color, and clarity also contribute to the value. These insights can help businesses make better pricing and inventory decisions.
""")
# Out:
# BUSINESS INSIGHT REPORT
#
# 1. Dataset was cleaned by checking missing values and removing duplicates.
# 2. Statistical measures such as mean, median, mode, variance, and standard deviation were calculated.
# 3. Correlation analysis showed relationships among numerical variables.
# 4. Outliers in diamond prices were identified using a box plot.
# 5. Scatter plot showed that larger carat diamonds generally have higher prices.
# 6. Bar chart displayed the distribution of diamond cuts.
# 7. Histogram showed the distribution of diamond prices.
#
# Conclusion:
# Diamond price is strongly influenced by carat weight, while cut, color, and clarity also contribute to the value. These insights can help businesses make better pricing and inventory decisions.
